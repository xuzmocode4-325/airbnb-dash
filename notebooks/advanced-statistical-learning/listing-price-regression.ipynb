# %%
import sys
import pandas as pd
from pathlib import Path

# %%
repo_root = Path.cwd().parents[1]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.normalisers import NormaliseListings

# %%
data_path = repo_root/'data'/'raw'
listings = pd.read_csv(data_path/'listings.csv.gz')

# %%
# Normalise Listings
listings_norm = NormaliseListings(listings)

# %%
unique_listings = listings_norm.normalise_listings()

# %%
unique_listings.head()
# Out:
#    listing_id       scrape_id  \
# 0       15007  20250928034929
# 1       15068  20250928034929
# 2       15077  20250928034929
# 3       15199  20250928034929
# 4       15354  20250928034929
#
#                                                 name  \
# 0    Blaauwberg House on the beach in Bloubergstrand
# 1                                         Grande Bay
# 2                      Relaxed beach living in style
# 3                            Self catering apartment
# 4  Aurora Self Catering Units, Durbanville, Cape ...
#
#                                          description  host_id   latitude  \
# 0  Welcome to our self-catering beach-front famil...    59072 -33.800010
# 1  Modern spacious apartment.  Three bedrooms two...    59318 -33.788260
# 2  Our Superior Rooms (approx. 25 m²) are located...    59342 -33.858356
# 3                                                NaN    59694 -33.911150
# 4  Durbanville is centrally located for daytrips ...    60196 -33.830740
#
#    longitude        property_type         room_type  accommodates  bathrooms  \
# 0  18.460630                 home  entire residence             6        3.0
# 1  18.459400          rental unit  entire residence             6        2.0
# 2  18.490376  room in rental unit      private room             2        1.0
# 3  18.412350          rental unit  entire residence             2        1.0
# 4  18.631420          guest suite  entire residence             3        NaN
#
#    bathrooms_text  bedrooms  beds  \
# 0         3 baths       3.0   4.0
# 1         2 baths       3.0   5.0
# 2  1 private bath       1.0   2.0
# 3          1 bath       1.0   1.0
# 4          1 bath       2.0   NaN
#
#                                            amenities  price_usd  \
# 0  ["Bathtub", "Fire extinguisher", "Oven", "Port...     2315.0
# 1  ["Hangers", "TV with standard cable", "Wifi", ...     4785.0
# 2  ["Wifi", "Oven", "Beach essentials", "Body soa...     1118.0
# 3  ["Wifi", "Free parking on premises", "TV", "Wa...     2250.0
# 4  ["Fire extinguisher", "Hangers", "Wifi", "Free...       <NA>
#
#    estimated_occupancy_l365d  estimated_revenue_l365d  instant_bookable  \
# 0                          6                  13890.0             False
# 1                          0                      0.0             False
# 2                          0                      0.0             False
# 3                          0                      0.0             False
# 4                          0                      NaN             False
#
#    neighbourhood_id
# 0                23
# 1                23
# 2                 4
# 3               115
# 4               112
