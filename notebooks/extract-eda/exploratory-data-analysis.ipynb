# %%
import sys
import pandas as pd
from pathlib import Path

# %%
repo_root = Path.cwd().parents[1]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
data_path = repo_root/'data'/'raw'

reviews = pd.read_csv(data_path/'reviews.csv.gz')
listings = pd.read_csv(data_path/'listings.csv.gz')
calendar = pd.read_csv(data_path/'calendar.csv.gz')

# %% [markdown]
# ## Reviews EDA

# %%
reviews.shape
# Out:
# (664377, 6)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664377 entries, 0 to 664376
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     664377 non-null  int64
#  1   id             664377 non-null  int64
#  2   date           664377 non-null  object
#  3   reviewer_id    664377 non-null  int64
#  4   reviewer_name  664376 non-null  object
#  5   comments       664240 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 30.4+ MB

# %% [markdown]
# How many `id` columns are in the reviews dataframe? How can they be used to subset the data and create relations?
#
# There are three `id` columns.
#
# `reviewer_id` - uniquely identifies reviewers
# `listing_id` - uniquely identifies listings
# `id` - uniquely identifies reviews
#
# To normalise this dataframe, any details related to `reviewers` will be stored in a separate table.

# %%
reviews_id_cols = [col for col in reviews if 'id' in col]
reviews_id_cols
# Out:
# ['listing_id', 'id', 'reviewer_id']

# %%
reviews.head() #NLP
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       15007   9223897  2013-12-15      7175290         Morne
# 1       15007  53759983  2015-11-12     13937367         Ciske
# 2       15007  55131160  2015-11-28     28986066      Samantha
# 3       15007  60945736  2016-01-30      6769287        Thomas
# 4       15007  61787988  2016-02-08     53613595          Inés
#
#                                             comments
# 0  We spent a fantastic two week holiday at the B...
# 1  Fabulous house in a stunning location! The lov...
# 2  The location of this lovey holiday home is 25m...
# 3  Communication & response very fast and reliabl...
# 4  The location of the house was great!!! the hou...

# %% [markdown]
# ## Listings EDA

# %%
listings.shape
# Out:
# (26877, 79)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26877 entries, 0 to 26876
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26877 non-null  int64
#  1   listing_url                                   26877 non-null  object
#  2   scrape_id                                     26877 non-null  int64
#  3   last_scraped                                  26877 non-null  object
#  4   source                                        26877 non-null  object
#  5   name                                          26876 non-null  object
#  6   description                                   26571 non-null  object
#  7   neighborhood_overview                         12832 non-null  object
#  8   picture_url                                   26877 non-null  object
#  9   host_id                                       26877 non-null  int64
#  10  host_url                                      26877 non-null  object
#  11  host_name                                     26871 non-null  object
#  12  host_since                                    26871 non-null  object
#  13  host_location                                 19807 non-null  object
#  14  host_about                                    13378 non-null  object
#  15  host_response_time                            20238 non-null  object
#  16  host_response_rate                            20238 non-null  object
#  17  host_acceptance_rate                          22947 non-null  object
#  18  host_is_superhost                             25778 non-null  object
#  19  host_thumbnail_url                            26871 non-null  object
#  20  host_picture_url                              26871 non-null  object
#  21  host_neighbourhood                            181 non-null    object
#  22  host_listings_count                           26871 non-null  float64
#  23  host_total_listings_count                     26871 non-null  float64
#  24  host_verifications                            26871 non-null  object
#  25  host_has_profile_pic                          26871 non-null  object
#  26  host_identity_verified                        26871 non-null  object
#  27  neighbourhood                                 12832 non-null  object
#  28  neighbourhood_cleansed                        26877 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      26877 non-null  float64
#  31  longitude                                     26877 non-null  float64
#  32  property_type                                 26877 non-null  object
#  33  room_type                                     26877 non-null  object
#  34  accommodates                                  26877 non-null  int64
#  35  bathrooms                                     22505 non-null  float64
#  36  bathrooms_text                                26641 non-null  object
#  37  bedrooms                                      26213 non-null  float64
#  38  beds                                          22649 non-null  float64
#  39  amenities                                     26877 non-null  object
#  40  price                                         22476 non-null  object
#  41  minimum_nights                                26877 non-null  int64
#  42  maximum_nights                                26877 non-null  int64
#  43  minimum_minimum_nights                        26875 non-null  float64
#  44  maximum_minimum_nights                        26875 non-null  float64
#  45  minimum_maximum_nights                        26875 non-null  float64
#  46  maximum_maximum_nights                        26875 non-null  float64
#  47  minimum_nights_avg_ntm                        26877 non-null  float64
#  48  maximum_nights_avg_ntm                        26877 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              25402 non-null  object
#  51  availability_30                               26877 non-null  int64
#  52  availability_60                               26877 non-null  int64
#  53  availability_90                               26877 non-null  int64
#  54  availability_365                              26877 non-null  int64
#  55  calendar_last_scraped                         26877 non-null  object
#  56  number_of_reviews                             26877 non-null  int64
#  57  number_of_reviews_ltm                         26877 non-null  int64
#  58  number_of_reviews_l30d                        26877 non-null  int64
#  59  availability_eoy                              26877 non-null  int64
#  60  number_of_reviews_ly                          26877 non-null  int64
#  61  estimated_occupancy_l365d                     26877 non-null  int64
#  62  estimated_revenue_l365d                       22476 non-null  float64
#  63  first_review                                  20753 non-null  object
#  64  last_review                                   20753 non-null  object
#  65  review_scores_rating                          20753 non-null  float64
#  66  review_scores_accuracy                        20752 non-null  float64
#  67  review_scores_cleanliness                     20752 non-null  float64
#  68  review_scores_checkin                         20749 non-null  float64
#  69  review_scores_communication                   20751 non-null  float64
#  70  review_scores_location                        20750 non-null  float64
#  71  review_scores_value                           20749 non-null  float64
#  72  license                                       129 non-null    object
#  73  instant_bookable                              26877 non-null  object
#  74  calculated_host_listings_count                26877 non-null  int64
#  75  calculated_host_listings_count_entire_homes   26877 non-null  int64
#  76  calculated_host_listings_count_private_rooms  26877 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   26877 non-null  int64
#  78  reviews_per_month                             20753 non-null  float64
# dtypes: float64(24), int64(20), object(35)
# memory usage: 16.2+ MB

# %% [markdown]
# How many `id` columns are in the **listings** dataframe? How can they be used to subset the data and create relations?
#
# There are two `id` columns.
#
# `host_id` - uniquely identifies hosts
# `scrape_id` - uniquely identifies scrapes
# `id` - uniquely identifies listings
#
# To normalise this dataframe, any details related to `hosts` and `scrapes` will be stored in a separate table.
#
# The listings table has also has another information subset related to `neighbourhoods` whicjhwill be stored in a separate table.
# Each neighbnourhood will be assigne a uniqe `neighbourhood_id`.
#
#
# Other details having a one-to-one relation with listings will be stored in respective tables related to their data catagory.
# This includes columns relating to `reviews`, `availability`, `minimum and maximum night parameters` as well as `neighbourhood overview`
# These information catagories an their respective column subets will be stored in separate tables an linked back to listing via `listing_id` column.

# %%
listings_id_cols = [col for col in listings.columns if 'id' in col]
listings_id_cols
# Out:
# ['id', 'scrape_id', 'host_id', 'host_identity_verified']

# %% [markdown]
# How many columns can be converted to categorical? Which columns are boolean types. To decide I am reviewing unique values per column.

# %%
unique_vals_per_column = []
for col in listings.columns: 
    col_dict = {}
    col_dict['col'] = col
    col_dict['n_unique'] = listings[col].nunique() 
    col_dict['n_null'] = listings[col].isna().sum()
    col_dict['null_ratio'] = listings[col].isna().sum() / listings.shape[0]
    unique_vals_per_column.append(col_dict)

# %%
df_col_info = pd.DataFrame(unique_vals_per_column)

# %%
len(df_col_info[df_col_info['n_null'] > 0])
# Out:
# 44

# %%
df_col_info[df_col_info['null_ratio'] > 0.9]
# Out:
#                              col  n_unique  n_null  null_ratio
# 21            host_neighbourhood        50   26696    0.993266
# 29  neighbourhood_group_cleansed         0   26877    1.000000
# 49              calendar_updated         0   26877    1.000000
# 72                       license        79   26748    0.995200

# %%
new_listings = listings.dropna(thresh=int(0.1*listings.shape[0]), axis=1)

# %% [markdown]
# ### Host Table Columns

# %%
# host table
new_listings = listings.dropna(thresh=int(0.1*listings.shape[0]), axis=1)
host_cols = [col for col in new_listings.columns if 'host' in col]
host_cols
# Out:
# ['host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms']

# %%
hosts = listings[host_cols]
hosts.drop_duplicates()
# Out:
#          host_id                                     host_url    host_name  \
# 0          59072      https://www.airbnb.com/users/show/59072         Dirk
# 1          59318      https://www.airbnb.com/users/show/59318        Linda
# 2          59342      https://www.airbnb.com/users/show/59342        Georg
# 3          59694      https://www.airbnb.com/users/show/59694        Alexa
# 4          60196      https://www.airbnb.com/users/show/60196          Ian
# ...          ...                                          ...          ...
# 26858  439366958  https://www.airbnb.com/users/show/439366958       Darren
# 26859  390482418  https://www.airbnb.com/users/show/390482418  Nokwethemba
# 26862  364777987  https://www.airbnb.com/users/show/364777987         Elsa
# 26868  720934718  https://www.airbnb.com/users/show/720934718        Seraj
# 26875  230384583  https://www.airbnb.com/users/show/230384583         Musa
#
#        host_since            host_location  \
# 0      2009-12-01  Cape Town, South Africa
# 1      2009-12-02                      NaN
# 2      2009-12-02                Gibraltar
# 3      2009-12-03  Cape Town, South Africa
# 4      2009-12-05  Cape Town, South Africa
# ...           ...                      ...
# 26858  2022-01-07  Cape Town, South Africa
# 26859  2021-02-28                      NaN
# 26862  2020-08-28    Altea la Vella, Spain
# 26868  2025-09-26                      NaN
# 26875  2018-12-12   London, United Kingdom
#
#                                               host_about  host_response_time  \
# 0      Proud to live in the beautiful city of Cape To...  within a few hours
# 1                                                    NaN  a few days or more
# 2               challenge us please! we love to perform!  within a few hours
# 3      Professional businesswoman dedicated to provid...                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 26858                                                NaN                 NaN
# 26859                                                NaN                 NaN
# 26862  Me llamo Elsa y soy la madre del huesped princ...      within an hour
# 26868                                                NaN                 NaN
# 26875                                                NaN                 NaN
#
#       host_response_rate host_acceptance_rate host_is_superhost  ...  \
# 0                   100%                  88%                 f  ...
# 1                     0%                  33%               NaN  ...
# 2                   100%                  80%                 f  ...
# 3                    NaN                  NaN               NaN  ...
# 4                    NaN                  NaN                 f  ...
# ...                  ...                  ...               ...  ...
# 26858                NaN                  NaN                 f  ...
# 26859                NaN                  NaN                 f  ...
# 26862               100%                  66%                 f  ...
# 26868                NaN                  NaN                 f  ...
# 26875                NaN                  NaN                 f  ...
#
#                                         host_picture_url host_listings_count  \
# 0      https://a0.muscache.com/im/pictures/user/86c72...                 7.0
# 1      https://a0.muscache.com/im/pictures/user/46fad...                 7.0
# 2      https://a0.muscache.com/im/pictures/user/User/...                 7.0
# 3      https://a0.muscache.com/im/pictures/user/e5264...                 2.0
# 4      https://a0.muscache.com/im/pictures/user/f3d66...                 1.0
# ...                                                  ...                 ...
# 26858  https://a0.muscache.com/im/pictures/user/243c0...                 1.0
# 26859  https://a0.muscache.com/im/pictures/user/8cee0...                 1.0
# 26862  https://a0.muscache.com/im/pictures/user/User/...                 5.0
# 26868  https://a0.muscache.com/im/pictures/user/User/...                 4.0
# 26875  https://a0.muscache.com/im/pictures/user/User/...                 1.0
#
#        host_total_listings_count                host_verifications  \
# 0                           19.0  ['email', 'phone', 'work_email']
# 1                           20.0                ['email', 'phone']
# 2                            7.0                ['email', 'phone']
# 3                            2.0                ['email', 'phone']
# 4                            2.0                ['email', 'phone']
# ...                          ...                               ...
# 26858                        2.0                ['email', 'phone']
# 26859                        1.0                         ['phone']
# 26862                        7.0                ['email', 'phone']
# 26868                        4.0                ['email', 'phone']
# 26875                        1.0                ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified  \
# 0                        t                      t
# 1                        t                      t
# 2                        t                      t
# 3                        t                      t
# 4                        t                      f
# ...                    ...                    ...
# 26858                    t                      t
# 26859                    t                      t
# 26862                    t                      t
# 26868                    t                      t
# 26875                    t                      t
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  5
# 2                                  6
# 3                                  1
# 4                                  1
# ...                              ...
# 26858                              1
# 26859                              1
# 26862                              1
# 26868                              4
# 26875                              1
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                1
# 1                                                5
# 2                                                1
# 3                                                1
# 4                                                1
# ...                                            ...
# 26858                                            1
# 26859                                            1
# 26862                                            1
# 26868                                            4
# 26875                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 5
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 26858                                             0
# 26859                                             0
# 26862                                             0
# 26868                                             0
# 26875                                             0
#
#        calculated_host_listings_count_shared_rooms
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 26858                                            0
# 26859                                            0
# 26862                                            0
# 26868                                            0
# 26875                                            0
#
# [14135 rows x 21 columns]

# %% [markdown]
# ### Neighbourhood Table

# %%
listings.rename(columns={'neighborhood_overview':'neighbourhood_overview'}, inplace=True)
neighbourhood_cols = [col for col in listings.columns if 'neighbourhood' in col]
neighbourhood_cols
# Out:
# ['neighbourhood_overview',
#  'host_neighbourhood',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed']

# %%
sum(listings['neighbourhood_overview'].isna() == listings['neighbourhood'].isna())
# Out:
# 26877

# %%
listings['neighbourhood'].isna().sum()
# Out:
# np.int64(14045)

# %%
new_neighbourhood_cols = [col for col in new_listings.columns if 'neighbourhood' in col]
new_neighbourhood_cols
# Out:
# ['neighbourhood', 'neighbourhood_cleansed']

# %%
listings.groupby('neighbourhood_cleansed')['id'].value_counts()
# Out:
# neighbourhood_cleansed  id
# Ward 1                  1871897                1
#                         1910455                1
#                         5137677                1
#                         8295789                1
#                         9851852                1
#                                               ..
# Ward 97                 1342785689425290569    1
#                         1342794590902319675    1
#                         1342799982469179115    1
#                         1343312702360540319    1
#                         1516644329466468131    1
# Name: count, Length: 26877, dtype: int64

# %%
listings['neighbourhood_id'] = listings['neighbourhood_cleansed'].map(lambda x: int(x.replace('Ward', '').strip()))

# %%
listings['neighbourhood_id'].value_counts()
# Out:
# neighbourhood_id
# 115    5715
# 54     4044
# 77     1616
# 23     1489
# 64     1226
#        ...
# 50        1
# 89        1
# 18        1
# 45        1
# 76        1
# Name: count, Length: 87, dtype: int64

# %%
listings
# Out:
#                         id                                       listing_url  \
# 0                    15007                https://www.airbnb.com/rooms/15007
# 1                    15068                https://www.airbnb.com/rooms/15068
# 2                    15077                https://www.airbnb.com/rooms/15077
# 3                    15199                https://www.airbnb.com/rooms/15199
# 4                    15354                https://www.airbnb.com/rooms/15354
# ...                    ...                                               ...
# 26872  1518767406168033995  https://www.airbnb.com/rooms/1518767406168033995
# 26873  1518774330832413817  https://www.airbnb.com/rooms/1518774330832413817
# 26874  1519068971681583983  https://www.airbnb.com/rooms/1519068971681583983
# 26875  1519071671116443933  https://www.airbnb.com/rooms/1519071671116443933
# 26876  1519109709313216069  https://www.airbnb.com/rooms/1519109709313216069
#
#             scrape_id last_scraped           source  \
# 0      20250928034929   2025-09-28      city scrape
# 1      20250928034929   2025-09-28      city scrape
# 2      20250928034929   2025-09-28      city scrape
# 3      20250928034929   2025-09-29      city scrape
# 4      20250928034929   2025-09-29  previous scrape
# ...               ...          ...              ...
# 26872  20250928034929   2025-09-29      city scrape
# 26873  20250928034929   2025-09-29      city scrape
# 26874  20250928034929   2025-09-28      city scrape
# 26875  20250928034929   2025-09-28      city scrape
# 26876  20250928034929   2025-09-28      city scrape
#
#                                                     name  \
# 0        Blaauwberg House on the beach in Bloubergstrand
# 1                                             Grande Bay
# 2                          Relaxed beach living in style
# 3                                Self catering apartment
# 4      Aurora Self Catering Units, Durbanville, Cape ...
# ...                                                  ...
# 26872                     Pont du Gard Sea Breeze Studio
# 26873       Brand new & secure Studio close to Sea Front
# 26874         Panoramic Views in a Premium Secure Estate
# 26875  Riverlands 2Bedroom Apartment with Mountain Views
# 26876                   Bluefin - Serene Lakeside Living
#
#                                              description  \
# 0      Welcome to our self-catering beach-front famil...
# 1      Modern spacious apartment.  Three bedrooms two...
# 2      Our Superior Rooms (approx. 25 m²) are located...
# 3                                                    NaN
# 4      Durbanville is centrally located for daytrips ...
# ...                                                  ...
# 26872  Views, views and more views! From Table Mounta...
# 26873  Welcome to our stylish and modern apartment in...
# 26874  Zinfandel is an exceptionally well maintained ...
# 26875  Modern 2-bedroom apartment in Riverlands with ...
# 26876  Nestled in an eco estate in Noordhoek, this ne...
#
#                                   neighbourhood_overview  \
# 0      Bloubergstrand is a lovely, cosy suburb near C...
# 1      Close to Eden on The Bay and lots of restauran...
# 2      It is probably the best hub in order to explor...
# 3                                                    NaN
# 4      Durbanville is a really lovely village half an...
# ...                                                  ...
# 26872                                                NaN
# 26873                                                NaN
# 26874                                                NaN
# 26875                                                NaN
# 26876                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/3b654aa4-248e...      59072  ...
# 1      https://a0.muscache.com/pictures/a09b3f0d-d43b...      59318  ...
# 2      https://a0.muscache.com/pictures/4a8fceaa-655e...      59342  ...
# 3      https://a0.muscache.com/pictures/142776/5b6c9e...      59694  ...
# 4      https://a0.muscache.com/pictures/113126/f1bb90...      60196  ...
# ...                                                  ...        ...  ...
# 26872  https://a0.muscache.com/pictures/hosting/Hosti...  235161727  ...
# 26873  https://a0.muscache.com/pictures/hosting/Hosti...  526736531  ...
# 26874  https://a0.muscache.com/pictures/hosting/Hosti...  165761197  ...
# 26875  https://a0.muscache.com/pictures/hosting/Hosti...  230384583  ...
# 26876  https://a0.muscache.com/pictures/hosting/Hosti...  165761197  ...
#
#       review_scores_location review_scores_value license instant_bookable  \
# 0                       4.94                4.85     NaN                f
# 1                        NaN                 NaN     NaN                f
# 2                       4.86                5.00     NaN                f
# 3                       5.00                4.00     NaN                f
# 4                        NaN                 NaN     NaN                f
# ...                      ...                 ...     ...              ...
# 26872                    NaN                 NaN     NaN                t
# 26873                    NaN                 NaN     NaN                t
# 26874                    NaN                 NaN     NaN                f
# 26875                    NaN                 NaN     NaN                f
# 26876                    NaN                 NaN     NaN                f
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  5
# 2                                  6
# 3                                  1
# 4                                  1
# ...                              ...
# 26872                              2
# 26873                              2
# 26874                             11
# 26875                              1
# 26876                             11
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               5
# 2                                               1
# 3                                               1
# 4                                               1
# ...                                           ...
# 26872                                           2
# 26873                                           2
# 26874                                          11
# 26875                                           1
# 26876                                          11
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                5
# 3                                                0
# 4                                                0
# ...                                            ...
# 26872                                            0
# 26873                                            0
# 26874                                            0
# 26875                                            0
# 26876                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                               0              0.33
# 1                                               0               NaN
# 2                                               0              0.05
# 3                                               0              0.01
# 4                                               0               NaN
# ...                                           ...               ...
# 26872                                           0               NaN
# 26873                                           0               NaN
# 26874                                           0               NaN
# 26875                                           0               NaN
# 26876                                           0               NaN
#
#       neighbourhood_id
# 0                   23
# 1                   23
# 2                    4
# 3                  115
# 4                  112
# ...                ...
# 26872              115
# 26873               54
# 26874               69
# 26875               57
# 26876               69
#
# [26877 rows x 80 columns]

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  15007  https://www.airbnb.com/rooms/15007  20250928034929   2025-09-28
# 1  15068  https://www.airbnb.com/rooms/15068  20250928034929   2025-09-28
# 2  15077  https://www.airbnb.com/rooms/15077  20250928034929   2025-09-28
# 3  15199  https://www.airbnb.com/rooms/15199  20250928034929   2025-09-29
# 4  15354  https://www.airbnb.com/rooms/15354  20250928034929   2025-09-29
#
#             source                                               name  \
# 0      city scrape    Blaauwberg House on the beach in Bloubergstrand
# 1      city scrape                                         Grande Bay
# 2      city scrape                      Relaxed beach living in style
# 3      city scrape                            Self catering apartment
# 4  previous scrape  Aurora Self Catering Units, Durbanville, Cape ...
#
#                                          description  \
# 0  Welcome to our self-catering beach-front famil...
# 1  Modern spacious apartment.  Three bedrooms two...
# 2  Our Superior Rooms (approx. 25 m²) are located...
# 3                                                NaN
# 4  Durbanville is centrally located for daytrips ...
#
#                               neighbourhood_overview  \
# 0  Bloubergstrand is a lovely, cosy suburb near C...
# 1  Close to Eden on The Bay and lots of restauran...
# 2  It is probably the best hub in order to explor...
# 3                                                NaN
# 4  Durbanville is a really lovely village half an...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/3b654aa4-248e...    59072  ...
# 1  https://a0.muscache.com/pictures/a09b3f0d-d43b...    59318  ...
# 2  https://a0.muscache.com/pictures/4a8fceaa-655e...    59342  ...
# 3  https://a0.muscache.com/pictures/142776/5b6c9e...    59694  ...
# 4  https://a0.muscache.com/pictures/113126/f1bb90...    60196  ...
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.94                4.85     NaN                f
# 1                    NaN                 NaN     NaN                f
# 2                   4.86                5.00     NaN                f
# 3                   5.00                4.00     NaN                f
# 4                    NaN                 NaN     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              5                                           5
# 2                              6                                           1
# 3                              1                                           1
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            5
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.33
# 1                                           0               NaN
# 2                                           0              0.05
# 3                                           0              0.01
# 4                                           0               NaN
#
#   neighbourhood_id
# 0               23
# 1               23
# 2                4
# 3              115
# 4              112
#
# [5 rows x 80 columns]

# %%
host_and_neighbourhood_cols = host_cols+neighbourhood_cols

# %%
not_host_or_neighbourhood = [col for col in listings.columns if col not in host_and_neighbourhood_cols]

# %%
listings[not_host_or_neighbourhood].columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'picture_url', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms',
#        'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'reviews_per_month', 'neighbourhood_id'],
#       dtype='object')

# %%
nights_data = [col for col in listings.columns if 'nights' in col]
nights_data
# Out:
# ['minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm']

# %%
listings.dropna(subset=nights_data).shape
# Out:
# (26875, 80)

# %%
availability_data = [col for col in listings.columns if 'availability' in col]
availability_data
# Out:
# ['has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'availability_eoy']

# %%
listings[availability_data].info()
listings[availability_data].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26877 entries, 0 to 26876
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   has_availability  25402 non-null  object
#  1   availability_30   26877 non-null  int64
#  2   availability_60   26877 non-null  int64
#  3   availability_90   26877 non-null  int64
#  4   availability_365  26877 non-null  int64
#  5   availability_eoy  26877 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ MB
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               13               31               50
# 1                t                0                0                0
# 2                t               22               52               61
# 3                t               30               60               90
# 4              NaN                0                0                0
#
#    availability_365  availability_eoy
# 0               230                50
# 1               264                 0
# 2               314                63
# 3               365                94
# 4                 0                 0

# %%
listings['has_availability'].value_counts()
# Out:
# has_availability
# t    25402
# Name: count, dtype: int64

# %%
obj_cols = [col for col in listings[not_host_or_neighbourhood].columns if listings[col].dtype == 'object']
obj_cols
# Out:
# ['listing_url',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'picture_url',
#  'property_type',
#  'room_type',
#  'bathrooms_text',
#  'amenities',
#  'price',
#  'has_availability',
#  'calendar_last_scraped',
#  'first_review',
#  'last_review',
#  'license',
#  'instant_bookable']

# %%
listings[obj_cols][['has_availability', 'instant_bookable', 'license']].head()
# Out:
#   has_availability instant_bookable license
# 0                t                f     NaN
# 1                t                f     NaN
# 2                t                f     NaN
# 3                t                f     NaN
# 4              NaN                f     NaN

# %%
listings['instant_bookable'].value_counts()
# Out:
# instant_bookable
# f    19266
# t     7611
# Name: count, dtype: int64

# %%
listings['instant_bookable'] = listings['instant_bookable'] == 't'
listings['instant_bookable']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26872     True
# 26873     True
# 26874    False
# 26875    False
# 26876    False
# Name: instant_bookable, Length: 26877, dtype: bool

# %%
url_data = [col for col in listings.columns if 'url' in col]
url_data
# Out:
# ['listing_url',
#  'picture_url',
#  'host_url',
#  'host_thumbnail_url',
#  'host_picture_url']

# %%
listing_reveiws_cols  = [col for col in listings.columns if 'review' in col]
listing_reveiws_cols
# Out:
# ['number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'number_of_reviews_ly',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'reviews_per_month']

# %% [markdown]
# ## Calendar EDA

# %%
calendar.shape
# Out:
# (9810109, 7)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9810109 entries, 0 to 9810108
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 523.9+ MB

# %%
calendar.head()
# Out:
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0     5295177  2025-09-29         f    NaN             NaN               1
# 1     5295177  2025-09-30         f    NaN             NaN               1
# 2     5295177  2025-10-01         t    NaN             NaN               1
# 3     5295177  2025-10-02         t    NaN             NaN               1
# 4     5295177  2025-10-03         t    NaN             NaN               1
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
calendar.isna().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price             9810109
# adjusted_price    9810109
# minimum_nights          0
# maximum_nights          0
# dtype: int64
